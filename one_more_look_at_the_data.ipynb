# %%
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
img_dir = '/tmp/imdb_crop/01'
mat_file = '/tmp/imdb_crop/imdb.mat'

# %%
import scipy.io
mat_data = scipy.io.loadmat(mat_file)

# %%
data_table = mat_data['imdb'][0][0]

# %%
for i in data_table:
    print(i[0,0])
# Out:
# 693726
# 1968
# [u'01/nm0000001_rm124825600_1899-5-10_1968.jpg']
# 1.0
# [u'Fred Astaire']
# [[ 1072.926   161.838  1214.784   303.696]]
# 1.45969291362
# 1.11897335716
# [u"'Lee' George Quinones"]
# 6488

# %%
from scipy import misc
import glob
from collections import defaultdict

images = []
filenames = []
sizes = defaultdict(int)
for filename in glob.glob(img_dir+'/*'):
    filenames.append(filename)
    im=misc.imread(filename)
    images.append(im)
    sizes[im.shape[0]] += 1

# %%
plt.scatter(sizes.keys(),sizes.values())

# %%
img_sample = np.random.choice(images, 10)

# %%
import matplotlib.pyplot as plt
for im in img_sample:
    plt.imshow(im)
    plt.show()
